# %%
import pandas as pd

# %%
#Lecture du fichier CSV avec encodage latin
df = pd.read_csv("Nexa_Store_Dataset_0.2.csv", encoding="latin", low_memory=False )

# %%
#Visualisation des premières lignes du DataFrame
df.head()
# Out:
#    ID de ligne ID de commande DaTe de commande Date dexpedition  \
# 0        45271   TZ-2014-6820       06-11-2024        08-11-2024
# 1        45637   SG-2014-4440       09-10-2024        10-10-2014
# 2        45638   SG-2014-4440       09-10-2024        10-10-2024
# 3        45945   CG-2013-2440       06-11-2023        08-11-2023
# 4        46149   EG-2014-5980       19-09-2024        20-09-2024
#
#   Mode dexpedition iD client Nom du client   Segment de marche      Ville  \
# 0   Premiere classe   LT-7110  Liz Thompson  Client particulier     Mwanza
# 1   Premiere classe   GH-4425    Gary Hwang  Client particulier      Dakar
# 2   Premiere classe   GH-4425    Gary Hwang  Client particulier      Dakar
# 3   Premiere classe   EJ-3720     Ed Jacobs  Client particulier  Kisangani
# 4   Premiere classe   CR-2730  Craig Reiter  Client particulier      Cairo
#
#   Etat / province  ...  Ventes  Quantite remise Profit Cout dexpedition  \
# ...

# %%
#Affichage des informations sur le DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51229 entries, 0 to 51228
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID de ligne              51229 non-null  int64
#  1   ID de commande           51229 non-null  object
#  2   DaTe de commande         51229 non-null  object
#  3   Date dexpedition        51229 non-null  object
#  4   Mode dexpedition        51229 non-null  object
#  5   iD client                51229 non-null  object
#  6   Nom du client            51229 non-null  object
#  7   Segment de marche        51229 non-null  object
#  8   Ville                    51229 non-null  object
#  9   Etat / province          51229 non-null  object
#  10  Pays                     51229 non-null  object
#  11  Code postal              10001 non-null  float64
#  12  Marche                   51229 non-null  object
#  13  Region                   51229 non-null  object
# ...

# %%
#Affichage des statistiques descriptives du DataFrame
df.describe()
# Out:
#         ID de ligne   Code postal      Quantite        remise  Unnamed: 26
# count  51229.000000  10001.000000  51229.000000  51229.000000          0.0
# mean   25605.715766  55195.557044      3.477444      0.143343          NaN
# std    14790.028551  32066.296709      2.280144      0.212976          NaN
# min        1.000000   1040.000000    -12.000000      0.000000          NaN
# 25%    12804.000000  23223.000000      2.000000      0.000000          NaN
# 50%    25593.000000  56560.000000      3.000000      0.000000          NaN
# 75%    38390.000000  90008.000000      5.000000      0.200000          NaN
# max    51290.000000  99301.000000     14.000000      1.700000          NaN

# %%
#liste des colonnes
columns = df.columns.tolist()
columns
# Out:
# ['ID de ligne',
#  'ID de commande',
#  'DaTe de commande',
#  'Date d\x92expedition',
#  'Mode d\x92expedition',
#  'iD client',
#  'Nom du client',
#  'Segment de marche',
#  'Ville',
#  'Etat / province',
#  'Pays',
#  'Code postal',
#  'Marche',
#  'Region',
#  'Id du Produit',
#  'categorie',
#  'Sous-categorie',
#  'Nom du Produit',
#  'Ventes',
#  'Quantite',
#  'remise',
#  'Profit',
#  'Cout d\x92expedition',
#  'Priorite de la commande',
#  'Sous-categorie.1',
#  'Nom du Produit.1',
#  'Unnamed: 26',
#  'Source de la commande']

# %%
#Analyse des valeurs manquantes dans chaque colonne
missing_values = df.isnull().sum()
missing_values

# %%
# Exploration des valeurs uniques dans la colonne 'ID de ligne'
df['ID de ligne'].unique()
# Out:
# array([45271, 45637, 45638, ..., 39465, 40584, 41196])

# %%
#Exploration des valeurs uniques dans la colonne 'ID de commande'
df['ID de commande'].unique()
# Out:
# array(['TZ-2014-6820', 'SG-2014-4440', 'CG-2013-2440', ...,
#        'US-2012-138919', 'CA-2013-154662', 'US-2011-117380'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'DaTe de commande'
df['DaTe de commande'].unique()
# Out:
# array(['06-11-2024', '09-10-2024', '06-11-2023', ..., '08-09-2023',
#        '24-04-2021', '23-03-2024'], dtype=object)

# %%
#exploration des valeurs uniques dans la colonne 'Date d\x92expedition'
df['Date d\x92expedition'].unique()
# Out:
# array(['08-11-2024', '10-10-2014', '10-10-2024', ..., '31-07-2023',
#        '06-01-2021', '05-01-2021'], dtype=object)

# %%
3#Exploration des valeurs uniques dans la colonne 'Mode d\x92expedition'
df['Mode d\x92expedition'].unique()
# Out:
# array(['Premiere classe', 'Meme jour', 'Deuxieme classe',
#        'Classe standard'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'iD client'
df['iD client'].unique()
# Out:
# array(['LT-7110', 'GH-4425', 'EJ-3720', ..., 'BD-1605', 'ME-8010',
#        'BG-1035'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Nom du client'
df['Nom du client'].unique()

# %%
#Exploration des valeurs uniques dans la colonne 'Segment de marche'
df['Segment de marche'].unique()

# %%
#Exploration des valeurs uniques dans la colonne 'Etat / province'
df['Etat / province'].unique()
# Out:
# array(['Mwanza', 'Dakar', 'Orientale', ..., 'Kastamonu', 'Cojedes',
#        'Casanare'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Pays'
df['Pays'].unique()

# %%
#Exploration des valeurs uniques dans la colonne 'Code postal'
df['Code postal'].unique()

# %%
#Exploration des valeurs uniques dans la colonne 'Marche'
df['Marche'].unique()
# Out:
# array(['Afrique', 'APAC', 'Canada', 'Europe Moyen-Orient et Afrique',
#        'EMEA', 'EU', 'LATAM', 'US', 'Amerique Latine', 'Asie Pacifique'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Region'
df['Region'].unique()
# Out:
# array(['Afrique', 'Nord Asie', 'Centre Asie', 'SudEst Asie', 'Oceanie',
#        'Canada', 'EMEA', 'Centre', 'Nord', 'Sud', 'Caraibes', 'Est',
#        'Ouest'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Id du Produit'
df['Id du Produit'].unique()
# Out:
# array(['TEC-BEL-10001971', 'TEC-BEL-10003177', 'TEC-ENE-10002686', ...,
#        'FUR-TA-10004152', 'FUR-TA-10001691', 'FUR-TA-10004175'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'categorie'
df['categorie'].unique()
# Out:
# array(['Technologie', 'Fournitures de bureau', 'Mobilier', 'Technlogie',
#        'Fournitures de buro'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Sous-categorie'
df['Sous-categorie'].unique()
# Out:
# array(['Accessoires', 'Appliances', 'Art', 'Rangements', 'Bibliotheques',
#        'Chairs', 'Photocopieurs', 'Enveloppes', 'Agrafes', 'decoration',
#        'Etiquettes', 'Machines', 'Papier', 'Telephones', 'Rangement',
#        'Fournitures de bureau', 'Tables'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Nom du Produit'
df['Nom du Produit'].unique()
# Out:
# array(['Belkin Flash Drive, USB', 'Belkin Keyboard, Erganomic',
#        'Enermax Numeric Keypad, Erganomic', ...,
#        'Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops',
#        'Hon 30" x 60" Table with Locking Drawer',
#        'Riverside Furniture Oval Coffee Table, Oval End Table, End Table with Drawer'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Ventes'
df['Ventes'].unique()
# Out:
# array(['84,3', '81.69', '58.83', ..., '2036.86', '457.485', '-330.588'],
#       shape=(22999,), dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Quantite'
df['Quantite'].unique()
# Out:
# array([ -2,   1,   4,  14,   2,   8,   6,  10,   7,   3,   5,   9,  13,
#         11,  12, -10, -11,  -3,  -4, -12])

# %%
#Exploration des valeurs uniques dans la colonne 'Remise'
df['remise'].unique()
# Out:
# array([0.   , 1.7  , 0.7  , 0.47 , 0.5  , 0.1  , 0.45 , 0.4  , 0.6  ,
#        0.2  , 0.17 , 0.15 , 0.8  , 0.27 , 0.07 , 0.35 , 0.37 , 0.3  ,
#        0.32 , 0.25 , 0.65 , 0.002, 0.402, 0.202, 0.602, 0.55 , 0.57 ,
#        0.85 ])

# %%
#Exploration des valeurs uniques dans la colonne 'Profit'
df['Profit'].unique()
# Out:
# array(['27.78', '4.89', '6,45', ..., '366.6348', '-84.9615', '-143.2548'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Cout d'expedition'
df['Cout d\x92expedition'].unique()
# Out:
# array(['7.93', '16.18', '14.62', ..., '21.24', '75.37', '524.76'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Priorite de la commande'
df['Priorite de la commande'].unique()
# Out:
# array(['Moyen', 'Critique', 'Eleve', 'Moten', 'Critic', 'Faible',
#        'Moyenne', 'moyen'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Sous-categorie.1'
df['Sous-categorie.1'].unique()
# Out:
# array(['Accessoires', 'Appliances', 'Art', 'Rangements', 'Bibliotheques',
#        'Chairs', 'Photocopieurs', 'Enveloppes', 'Agrafes', 'decoration',
#        'Etiquettes', 'Machines', 'Papier', 'Telephones', 'Rangement',
#        'Fournitures de bureau', 'Tables'], dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Nom du Produit.1'
df['Nom du Produit.1'].unique()
# Out:
# array(['Belkin Flash Drive, USB', 'Belkin Keyboard, Erganomic',
#        'Enermax Numeric Keypad, Erganomic', ...,
#        'Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops',
#        'Hon 30" x 60" Table with Locking Drawer',
#        'Riverside Furniture Oval Coffee Table, Oval End Table, End Table with Drawer'],
#       dtype=object)

# %%
#Exploration des valeurs uniques dans la colonne 'Source de la commande
df['Source de la commande'].unique()
# Out:
# array(['en ligne'], dtype=object)
